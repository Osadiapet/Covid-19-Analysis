# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('covid_data.csv')
data
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      16/10/2020   16     10  2020      0       0             Afghanistan
# 1      15/10/2020   15     10  2020     32       1             Afghanistan
# 2      14/10/2020   14     10  2020     66       0             Afghanistan
# 3      13/10/2020   13     10  2020    129       3             Afghanistan
# 4      12/10/2020   12     10  2020     96       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 49357  25/03/2020   25      3  2020      0       0                Zimbabwe
# 49358  24/03/2020   24      3  2020      0       1                Zimbabwe
# 49359  23/03/2020   23      3  2020      0       0                Zimbabwe
# 49360  22/03/2020   22      3  2020      1       0                Zimbabwe
# 49361  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
data.shape
# Out:
# (49362, 12)

# %%
#removing all null values from our dataset
data=data.dropna()
data
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      16/10/2020   16     10  2020      0       0             Afghanistan
# 1      15/10/2020   15     10  2020     32       1             Afghanistan
# 2      14/10/2020   14     10  2020     66       0             Afghanistan
# 3      13/10/2020   13     10  2020    129       3             Afghanistan
# 4      12/10/2020   12     10  2020     96       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 49344  07/04/2020    7      4  2020      0       0                Zimbabwe
# 49345  06/04/2020    6      4  2020      0       0                Zimbabwe
# 49346  05/04/2020    5      4  2020      0       0                Zimbabwe
# 49347  04/04/2020    4      4  2020      1       0                Zimbabwe
# 49348  03/04/2020    3      4  2020      0       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
data.shape
# Out:
# (46377, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46377 entries, 0 to 49348
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     46377 non-null  object
#  1   day                                                         46377 non-null  int64
#  2   month                                                       46377 non-null  int64
#  3   year                                                        46377 non-null  int64
#  4   cases                                                       46377 non-null  int64
#  5   deaths                                                      46377 non-null  int64
#  6   countriesAndTerritories                                     46377 non-null  object
# ...

# %%
data.describe()
# Out:
#                 day         month     year         cases        deaths  \
# count  46377.000000  46377.000000  46377.0  46377.000000  46377.000000
# mean      15.623930      6.269552   2020.0    840.095284     23.693620
# std        8.790645      2.325000      0.0   4846.202756    129.838528
# min        1.000000      1.000000   2020.0  -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.0      0.000000      0.000000
# 50%       15.000000      6.000000   2020.0     15.000000      0.000000
# 75%       23.000000      8.000000   2020.0    209.000000      4.000000
# max       31.000000     10.000000   2020.0  97894.000000   4928.000000
#
#         popData2019  \
# count  4.637700e+04
# mean   4.265764e+07
# std    1.572207e+08
# min    8.150000e+02
# 25%    1.355982e+06
# 50%    8.519373e+06
# 75%    2.916192e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# count                                       46377.000000
# ...

# %%
data.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
#total number of cases recorded as at 16/10/2020
cases=data['cases'].sum()
cases
# Out:
# 38961099

# %%
#total number of deaths
death=data['deaths'].sum()
death
# Out:
# 1098839

# %%
#percentage of death
death_percentage=death/cases*100
death_percentage
# Out:
# 2.82034908717539

# %%
#survived 
survived=cases-death
survived
# Out:
# 37862260

# %%
#percentage of survived patients 
per_survived =survived/cases*100
per_survived
# Out:
# 97.17965091282461

# %%
#worldwide population as at 2019
world_population=data['popData2019'].sum()
world_population
# Out:
# 1978333343943.0

# %%
#percestage of people who had the covid worldwide per 100000 persons
covid_persons=cases/world_population*100000
covid_persons
# Out:
# 1.9693899978628957

# %%
continents=data.groupby(['continentExp']).sum()
continents
# Out:
#                  day  month      year     cases  deaths   popData2019  \
# continentExp
# Africa        167814  72590  21852360   1601207   38927  2.860570e+11
# America       158603  66993  20616120  18504025  603311  2.604507e+11
# Asia          163904  61871  21050420  12153401  217864  1.218559e+12
# Europe        207604  78264  26680160   6665992  237724  2.029135e+11
# Oceania        26666  11045   3482480     36474    1013  1.035351e+10
#
#               Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# continentExp
# Africa                                            121110.538443
# America                                           585551.841262
# Asia                                              421702.170341
# Europe                                            613279.245660
# Oceania                                            41400.300410

# %%
#number of cases recorded by each continent
continents['cases']
# Out:
# continentExp
# Africa      1601207
# America    18504025
# Asia       12153401
# Europe      6665992
# Oceania       36474
# Name: cases, dtype: int64

# %%
continents['cases'].plot.bar()
plt.title('Graphical distribution of recorded number of cases for each continents')
plt.xlabel("Continent")
plt.ylabel('Number of cases')
plt.ylim(0,20000000)
plt.show()

# %%
#number of covid death recorded by each continent
continents['deaths']
# Out:
# continentExp
# Africa      38927
# America    603311
# Asia       217864
# Europe     237724
# Oceania      1013
# Name: deaths, dtype: int64

# %%
continents['deaths'].plot.bar()
plt.title('Graphical distribution of recorded number of death cases for each continents')
plt.xlabel("Continent")
plt.ylabel('Number of death cases')
plt.show()

# %%
continents[['cases', 'deaths']].plot.bar()
plt.title('comparison of recorded cases and number of deaths for each continents')
plt.xlabel("Continent")
plt.ylabel('Number of recorded death cases')
plt.show()

# %%
continent_covid_percent=continents['cases']/continents['popData2019']*100
continents['continent_covid_percent']=continent_covid_percent
continent_death_percent=continents['deaths']/continents['cases']*100
continents['continent_death_percent']=continent_death_percent
continent_overall_covid_percent=continents['cases']/sum(data['cases'])*100
continents['continent_overall_covid_percent']=continent_overall_covid_percent
continent_overall_death_percent=continents['deaths']/sum(data['deaths'])*100
continents['continent_overall_death_percent']=continent_overall_death_percent

# %%
continent1=continents[['cases','deaths','continent_death_percent','continent_covid_percent','continent_overall_covid_percent',
                      'continent_overall_death_percent']]
continent1
# Out:
#                  cases  deaths  continent_death_percent  \
# continentExp
# Africa         1601207   38927                 2.431104
# America       18504025  603311                 3.260431
# Asia          12153401  217864                 1.792618
# Europe         6665992  237724                 3.566221
# Oceania          36474    1013                 2.777321
#
#               continent_covid_percent  continent_overall_covid_percent  \
# continentExp
# Africa                       0.000560                         4.109758
# America                      0.007105                        47.493591
# Asia                         0.000997                        31.193681
# Europe                       0.003285                        17.109353
# Oceania                      0.000352                         0.093616
#
#               continent_overall_death_percent
# continentExp
# Africa                               3.542557
# America                             54.904404
# ...

# %%
plt.pie(continent1['continent_overall_covid_percent'],labels=('Africa','America','Asia','Europe','Oceania'),autopct='%1.1f%%')
plt.title('percentage of covid cases in the continnts with respect to total recorded cases')
plt.show()

# %%
plt.pie(continent1['continent_overall_death_percent'],labels=('Africa','America','Asia','Europe','Oceania'), autopct='%1.1f%%' )
plt.title("Percentage of covid death cases with respect to worldwide recorded death cases in the various continents")
plt.show()

# %%
#death percentage of continents with respect to their population
continent1['continent_death_percent'].plot.bar()
plt.title('Percentage of covid death cases per continent with respect to their total population')
plt.xlabel('Continent')
plt.ylabel('percentage of covid death per recorded cases')
plt.show()

# %%
#percentage of covid 19 cases of continents with respect to their population 
continent1['continent_covid_percent'].plot.bar()
plt.title('Percentage of covid cases per continent with respect to their total population')
plt.xlabel('Continent')
plt.ylabel('percentage of covid cases per population')
plt.show()

# %%
continent1[['continent_covid_percent','continent_death_percent']].plot.bar()
plt.title('comparing Percentage of covid death cases with respect to their total cases')
plt.xlabel('Continent')
plt.ylabel('percentage of covid cases per population')
plt.show()

# %%
#countries that recorded the covid cases
countries=data['countriesAndTerritories'].unique()
countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua_and_Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire, Saint Eustatius and Saba', 'Bosnia_and_Herzegovina',
#        'Botswana', 'Brazil', 'British_Virgin_Islands',
#        'Brunei_Darussalam', 'Bulgaria', 'Burkina_Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape_Verde', 'Cayman_Islands',
#        'Central_African_Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Costa_Rica', 'Cote_dIvoire', 'Croatia',
#        'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        'Democratic_Republic_of_the_Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican_Republic', 'Ecuador', 'Egypt',
#        'El_Salvador', 'Equatorial_Guinea', 'Eritrea', 'Estonia',
# ...

# %%
#number of countries that recorded covid cases
len(countries)
# Out:
# 208

# %%
country=data.groupby(['countriesAndTerritories']).sum()
country
# Out:
#                           day  month    year  cases  deaths   popData2019  \
# countriesAndTerritories
# Afghanistan              4285   1490  541360  40026    1481  1.019519e+10
# Albania                  3284   1380  422180  16142     437  5.982472e+08
# Algeria                  4329   1505  551460  53777    1836  1.175348e+10
# Andorra                  3164   1365  412080   3002      59  1.554011e+07
# Angola                   3013   1338  395920   6838     225  6.237759e+09
# ...                       ...    ...     ...    ...     ...           ...
# Vietnam                  4350   1508  553480   1124      35  2.643062e+10
# Western_Sahara           2518   1190  325220    760       1  9.377574e+07
# Yemen                    2766   1262  357540   2056     597  5.161660e+09
# Zambia                   3019   1350  401980  15624     346  3.554346e+09
# Zimbabwe                 3016   1342  397940   8067     230  2.885158e+09
#
# ...

# %%
#looking at countries that recorded the highest number of covid cases
highest_covid=country['cases'].sort_values(ascending =False)
highest_covid
# Out:
# countriesAndTerritories
# United_States_of_America       7979885
# India                          7370468
# Brazil                         5169386
# Russia                         1354163
# Argentina                       948953
#                                 ...
# Saint_Kitts_and_Nevis                8
# Montserrat                           8
# Greenland                            6
# Falkland_Islands_(Malvinas)          2
# Anguilla                             0
# Name: cases, Length: 208, dtype: int64

# %%
#graphical representation of countries that recorded high covid 19 cases
highest_covid.head(20).plot.bar()
plt.title("Distribution of countries that recorded high covid 19 cases")
plt.xlabel('Country')
plt.ylabel('Number of cases')
plt.show()

# %%
#looking at countries that recorded the highest covid death
country['deaths'].sort_values(ascending=False)
# Out:
# countriesAndTerritories
# United_States_of_America    217700
# Brazil                      152460
# India                       112161
# Mexico                       85285
# United_Kingdom               43293
#                              ...
# Eritrea                          0
# Dominica                         0
# Curaçao                          0
# Cayman_Islands                   0
# Grenada                          0
# Name: deaths, Length: 208, dtype: int64

# %%
#graphical representation of countries that recorded high covid 19 death cases
country['deaths'].sort_values(ascending=False).head(20).plot.bar()
plt.title("Distribution of countries that recorded high covid 19 death cases")
plt.xlabel('Country')
plt.ylabel('Number of death cases')
plt.show()

# %%
death_percent=country['deaths']/country['cases']*100
country['death_percent']=death_percent
covid_percent=country['cases']/country['popData2019']*100
country['covid_percent']=covid_percent

# %%
#distribution to show the percentage of covid cases in each country 
country1=country[['cases','deaths','death_percent','covid_percent']]
country1
# Out:
#                          cases  deaths  death_percent  covid_percent
# countriesAndTerritories
# Afghanistan              40026    1481       3.700095       0.000393
# Albania                  16142     437       2.707223       0.002698
# Algeria                  53777    1836       3.414099       0.000458
# Andorra                   3002      59       1.965356       0.019318
# Angola                    6838     225       3.290436       0.000110
# ...                        ...     ...            ...            ...
# Vietnam                   1124      35       3.113879       0.000004
# Western_Sahara             760       1       0.131579       0.000810
# Yemen                     2056     597      29.036965       0.000040
# Zambia                   15624     346       2.214542       0.000440
# Zimbabwe                  8067     230       2.851122       0.000280
#
# [208 rows x 4 columns]

# %%
#countries with high percentage of covid deaths 
country1['death_percent'].sort_values(ascending=False)
# Out:
# countriesAndTerritories
# Yemen            29.036965
# Montserrat       12.500000
# Mexico           10.214873
# Italy             9.531397
# Isle_of_Man       8.480565
#                    ...
# Cambodia          0.000000
# New_Caledonia     0.000000
# Timor_Leste       0.000000
# Gibraltar         0.000000
# Anguilla               NaN
# Name: death_percent, Length: 208, dtype: float64

# %%
country1['death_percent'].sort_values(ascending=False).head(20).plot.bar()
plt.title("Graphical representation of countries with high rate of covid deaths")
plt.xlabel('Country')
plt.ylabel('Death Percentage')
plt.show()

# %%
#countries that recorded massively with respect to their population
country1['covid_percent'].sort_values(ascending=False)
# Out:
# countriesAndTerritories
# Aruba                          2.037100e-02
# Andorra                        1.931776e-02
# Bahrain                        1.692776e-02
# Qatar                          1.659859e-02
# Panama                         1.388471e-02
#                                    ...
# Cambodia                       6.381233e-06
# United_Republic_of_Tanzania    4.254189e-06
# Vietnam                        4.252644e-06
# Laos                           8.672369e-07
# Anguilla                       0.000000e+00
# Name: covid_percent, Length: 208, dtype: float64

# %%
country1['covid_percent'].sort_values(ascending=False).head(20).plot.bar()
plt.title("Graphical representation of countries with high recorded rate of covid with respect to their population ")
plt.xlabel('Country')
plt.ylabel('covid Percentage')
plt.show()

# %%
monthly=data.groupby(['month']).sum()
monthly
# Out:
#           day      year    cases  deaths   popData2019  \
# month
# 1       27588   2533080     9765     212  1.102120e+11
# 2       28710   3866280    74707    2702  1.682183e+11
# 3       44706   4680340   713118   35608  1.773923e+11
# 4       92999  11724080  2329656  189100  2.271054e+11
# 5      102558  12899720  2873352  140169  2.374732e+11
# 6       96702  12602780  4232814  134099  2.299731e+11
# 7      103168  13024960  7051295  166211  2.376684e+11
# 8      103168  13024960  7972116  178560  2.376684e+11
# 9       96720  12604800  8452149  162121  2.300016e+11
# 10      28272   6720540  5252127   90057  1.226206e+11
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# month
# 1                                               4.950429
# 2                                             150.000095
# 3                                           38165.688363
# 4                                          167941.962566
# ...

# %%
#looking at which month recorded the highest covid  cases
monthly['cases'].sort_values(ascending =False)
# Out:
# month
# 9     8452149
# 8     7972116
# 7     7051295
# 10    5252127
# 6     4232814
# 5     2873352
# 4     2329656
# 3      713118
# 2       74707
# 1        9765
# Name: cases, dtype: int64

# %%
monthly['cases'].sort_index().plot.bar()
plt.title("Number of cases recorded per each month")
plt.xlabel('Month')
plt.ylabel('Number of cases')
plt.show()

# %%
#looking at which month recorded highest covid deaths
monthly['deaths'].sort_values(ascending =False)
# Out:
# month
# 4     189100
# 8     178560
# 7     166211
# 9     162121
# 5     140169
# 6     134099
# 10     90057
# 3      35608
# 2       2702
# 1        212
# Name: deaths, dtype: int64

# %%
monthly['cases'].sort_index().plot.bar()
plt.title("Number of cases recorded per each month")
plt.xlabel('Month')
plt.ylabel('Number of cases')
plt.show()

# %%
data['month'].value_counts().sort_index().plot.bar()
plt.title('number of covid deaths recorded per month')
plt.xlabel('month')
plt.ylabel('Number of death cases')
plt.show()

# %%
#analysis on African continent
africa=data.loc[data['continentExp']=='Africa']
africa
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 503    16/10/2020   16     10  2020    193       9                 Algeria
# 504    15/10/2020   15     10  2020    185       9                 Algeria
# 505    14/10/2020   14     10  2020    174       9                 Algeria
# 506    13/10/2020   13     10  2020    153       8                 Algeria
# 507    12/10/2020   12     10  2020    132       6                 Algeria
# ...           ...  ...    ...   ...    ...     ...                     ...
# 49344  07/04/2020    7      4  2020      0       0                Zimbabwe
# 49345  06/04/2020    6      4  2020      0       0                Zimbabwe
# 49346  05/04/2020    5      4  2020      0       0                Zimbabwe
# 49347  04/04/2020    4      4  2020      1       0                Zimbabwe
# 49348  03/04/2020    3      4  2020      0       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
african_countries=africa.groupby(['countriesAndTerritories']).sum()
african_countries
# Out:
#                                    day  month    year   cases  deaths  \
# countriesAndTerritories
# Algeria                           4329   1505  551460   53777    1836
# Angola                            3013   1338  395920    6838     225
# Benin                             3080   1356  406020    2490      41
# Botswana                          2928   1298  375720    5229      19
# Burkina_Faso                      3190   1368  414100    2236      62
# Burundi                           2928   1298  375720     524       1
# Cameroon                          3190   1368  414100   21369     422
# Cape_Verde                        3016   1342  397940    7438      78
# Central_African_Republic          3109   1359  408040    4850      62
# Chad                              3018   1346  399960    1343      92
# Comoros                           2449   1160  313100     485       6
# Congo                             3109   1359  408040    5152      92
# ...

# %%
#african countries that recorded the highest number of covid cases
african_countries['cases'].sort_values(ascending =False)
# Out:
# countriesAndTerritories
# South_Africa                        698034
# Morocco                             163554
# Egypt                               105033
# Ethiopia                             87157
# Nigeria                              60834
# Algeria                              53777
# Ghana                                47105
# Libya                                46658
# Kenya                                43118
# Tunisia                              34736
# Cameroon                             21369
# Cote_dIvoire                         20177
# Madagascar                           16700
# Zambia                               15624
# Senegal                              15292
# Sudan                                13688
# Guinea                               11250
# Democratic_Republic_of_the_Congo     10924
# Mozambique                           10527
# Uganda                               10072
# Gabon                                 8863
# ...

# %%
african_countries['cases'].sort_values(ascending=False).head(20).plot.bar()
plt.title('Countries that recorede the highest covid 19 cases in africa')
plt.xlabel('Country')
plt.ylabel("Number of covid cases")
plt.show()

# %%
#African countries that recorded high death 
african_countries['deaths'].sort_values(ascending =False)
# Out:
# countriesAndTerritories
# South_Africa                        18309
# Egypt                                6088
# Morocco                              2769
# Algeria                              1836
# Ethiopia                             1325
# Nigeria                              1116
# Sudan                                 835
# Kenya                                 805
# Libya                                 680
# Tunisia                               511
# Cameroon                              422
# Zambia                                346
# Senegal                               316
# Ghana                                 307
# Democratic_Republic_of_the_Congo      277
# Madagascar                            237
# Zimbabwe                              230
# Angola                                225
# Malawi                                179
# Mauritania                            163
# Mali                                  127
# Cote_dIvoire                          121
# ...

# %%
african_countries['deaths'].sort_values(ascending=False).head(20).plot.bar()
plt.title('Countries that recoreded the highest covid 19 death cases in africa')
plt.xlabel('Country')
plt.ylabel("Number of covid death cases")
plt.show()

# %%
percentage_africa_cases=african_countries['cases']/african_countries['popData2019']*100
african_countries['percentage_africa_cases']=percentage_africa_cases
percentage_africa_death=african_countries['deaths']/african_countries['cases']*100
african_countries['percentage_africa_death']=percentage_africa_death

# %%
#Tabular distribution of african countries and their total covid cases and deaths
africa1=african_countries[['cases','deaths','percentage_africa_cases','percentage_africa_death']]
africa1
# Out:
#                                    cases  deaths  percentage_africa_cases  \
# countriesAndTerritories
# Algeria                            53777    1836                 0.000458
# Angola                              6838     225                 0.000110
# Benin                               2490      41                 0.000105
# Botswana                            5229      19                 0.001220
# Burkina_Faso                        2236      62                 0.000054
# Burundi                              524       1                 0.000024
# Cameroon                           21369     422                 0.000403
# Cape_Verde                          7438      78                 0.006866
# Central_African_Republic            4850      62                 0.000506
# Chad                                1343      92                 0.000043
# Comoros                              485       6                 0.000368
# ...

# %%
#countries that recorded high covid cases with respect to their population
africa1['percentage_africa_cases']
# Out:
# countriesAndTerritories
# Algeria                             0.000458
# Angola                              0.000110
# Benin                               0.000105
# Botswana                            0.001220
# Burkina_Faso                        0.000054
# Burundi                             0.000024
# Cameroon                            0.000403
# Cape_Verde                          0.006866
# Central_African_Republic            0.000506
# Chad                                0.000043
# Comoros                             0.000368
# Congo                               0.000474
# Cote_dIvoire                        0.000385
# Democratic_Republic_of_the_Congo    0.000061
# Djibouti                            0.002796
# Egypt                               0.000382
# Equatorial_Guinea                   0.001837
# Eritrea                             0.000057
# Eswatini                            0.002457
# Ethiopia                            0.000381
# ...

# %%
africa1['percentage_africa_cases'].sort_values(ascending=False).head(20).plot.bar()
plt.title('Graphical distribution of African countries that recorded high covid cases with respect to their population ')
plt.xlabel('Country')
plt.ylabel('percentage of covid cases with respect to country size')
plt.show()

# %%
#countries that recorded high covid death cases with respect to their population
africa1['percentage_africa_death']
# Out:
# countriesAndTerritories
# Algeria                             3.414099
# Angola                              3.290436
# Benin                               1.646586
# Botswana                            0.363358
# Burkina_Faso                        2.772809
# Burundi                             0.190840
# Cameroon                            1.974823
# Cape_Verde                          1.048669
# Central_African_Republic            1.278351
# Chad                                6.850335
# Comoros                             1.237113
# Congo                               1.785714
# Cote_dIvoire                        0.599693
# Democratic_Republic_of_the_Congo    2.535701
# Djibouti                            1.126085
# Egypt                               5.796274
# Equatorial_Guinea                   1.641614
# Eritrea                             0.000000
# Eswatini                            2.008032
# Ethiopia                            1.520245
# ...

# %%
africa1['percentage_africa_death'].sort_values(ascending=False).head(20).plot.bar()
plt.title('African countries that recorded high covid death cases with respect to their population ')
plt.xlabel('Country')
plt.ylabel('percentage of covid death cases with respect to their recorded cases')
plt.show()

# %%
#looking at which month recorded the highest covid cases and death
af_month=africa.groupby(['month']).sum()
af_month
# Out:
#          day     year   cases  deaths   popData2019  \
# month
# 1       1254   115140       0       0  6.543690e+09
# 2       1305   175740       3       0  9.987737e+09
# 3       5065   412080    3854     138  1.159554e+10
# 4      22793  2813860   31359    1414  3.755897e+10
# 5      26265  3282500  104867    2479  4.036271e+10
# 6      25110  3272400  251649    5807  3.913226e+10
# 7      26784  3381480  514435    9423  4.043666e+10
# 8      26784  3381480  331137   10212  4.043666e+10
# 9      25110  3272400  224361    6039  3.913226e+10
# 10      7344  1745280  139542    3415  2.087054e+10
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# month
# 1                                               0.000000
# 2                                               0.024232
# 3                                             104.753009
# 4                                            3279.521309
# 5                                           11109.028235
# ...

# %%
af_cases=af_month['cases']
af_cases
# Out:
# month
# 1          0
# 2          3
# 3       3854
# 4      31359
# 5     104867
# 6     251649
# 7     514435
# 8     331137
# 9     224361
# 10    139542
# Name: cases, dtype: int64

# %%
af_month['cases'].sort_index().plot.bar()
plt.title('Number of covid cases recorded in Africa per each month')
plt.xlabel('Month')
plt.ylabel('Number of cases')
plt.show()

# %%
af_death=af_month['deaths']
af_death
# Out:
# month
# 1         0
# 2         0
# 3       138
# 4      1414
# 5      2479
# 6      5807
# 7      9423
# 8     10212
# 9      6039
# 10     3415
# Name: deaths, dtype: int64

# %%
#number of deaths recorded in each month in Africa 
af_month['deaths'].sort_index()
# Out:
# month
# 1         0
# 2         0
# 3       138
# 4      1414
# 5      2479
# 6      5807
# 7      9423
# 8     10212
# 9      6039
# 10     3415
# Name: deaths, dtype: int64

# %%
af_month['deaths'].sort_index().plot.bar()
plt.title('Number of covid death cases recorded in Africa per each month')
plt.xlabel('Month')
plt.ylabel('Number of death cases')
# Out:
# Text(0, 0.5, 'Number of death cases')

# %%
#recorded cases and death per month in Africa 
af_month[['cases','deaths']]
# Out:
#         cases  deaths
# month
# 1           0       0
# 2           3       0
# 3        3854     138
# 4       31359    1414
# 5      104867    2479
# 6      251649    5807
# 7      514435    9423
# 8      331137   10212
# 9      224361    6039
# 10     139542    3415

# %%
af_month[['cases','deaths']].plot(kind="bar")
plt.title('Number of covid cases and death recorded in Africa per each month')
plt.xlabel('Month')
plt.ylabel('Number of cases and death')
# Out:
# Text(0, 0.5, 'Number of cases and death')

# %%
#Focusing on Ghana 
Ghana=data.loc[data['countriesAndTerritories']=='Ghana']
Ghana
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 17805  16/10/2020   16     10  2020     47       0                   Ghana
# 17806  15/10/2020   15     10  2020      0       0                   Ghana
# 17807  14/10/2020   14     10  2020     96       2                   Ghana
# 17808  13/10/2020   13     10  2020     25       2                   Ghana
# 17809  12/10/2020   12     10  2020      0       0                   Ghana
# ...           ...  ...    ...   ...    ...     ...                     ...
# 18004  31/03/2020   31      3  2020      0       0                   Ghana
# 18005  30/03/2020   30      3  2020     11       0                   Ghana
# 18006  29/03/2020   29      3  2020      4       2                   Ghana
# 18007  28/03/2020   28      3  2020      5       0                   Ghana
# 18008  27/03/2020   27      3  2020     64       0                   Ghana
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
Ghana.shape
# Out:
# (204, 12)

# %%
Ghana.describe()
# Out:
#               day       month    year        cases      deaths  popData2019  \
# count  204.000000  204.000000   204.0   204.000000  204.000000        204.0
# mean    15.509804    6.691176  2020.0   230.906863    1.504902   30417858.0
# std      8.947295    1.959622     0.0   286.423669    2.740856          0.0
# min      1.000000    3.000000  2020.0     0.000000    0.000000   30417858.0
# 25%      8.000000    5.000000  2020.0     0.000000    0.000000   30417858.0
# 50%     15.000000    7.000000  2020.0   122.000000    0.000000   30417858.0
# 75%     23.000000    8.000000  2020.0   344.750000    2.000000   30417858.0
# max     31.000000   10.000000  2020.0  1513.000000   15.000000   30417858.0
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# count                                         204.000000
# mean                                           10.587289
# std                                             9.157168
# ...

# %%
Ghana[['cases','deaths','Cumulative_number_for_14_days_of_COVID-19_cases_per_100000']].corr()
# Out:
#                                                        cases    deaths  \
# cases                                               1.000000  0.358327
# deaths                                              0.358327  1.000000
# Cumulative_number_for_14_days_of_COVID-19_cases...  0.679761  0.342746
#
#                                                     Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# cases                                                                                        0.679761
# deaths                                                                                       0.342746
# Cumulative_number_for_14_days_of_COVID-19_cases...                                           1.000000

# %%
Gh_month=Ghana.groupby(['month']).sum()
Gh_month
# Out:
#        day   year  cases  deaths  popData2019  \
# month
# 3      145  10100     84       2  152089290.0
# 4      465  60600   1519      11  912535740.0
# 5      496  62620   6097      19  942953598.0
# 6      465  60600   9583      77  912535740.0
# 7      496  62620  17791      63  942953598.0
# 8      496  62620   9063     101  942953598.0
# 9      465  60600   2277      25  912535740.0
# 10     136  32320    691       9  486685728.0
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# month
# 3                                               2.307855
# 4                                              51.295525
# 5                                             255.123158
# 6                                             364.266281
# 7                                             749.533383
# 8                                             580.846291
# 9                                             117.782784
# 10                                             38.651637

# %%
#looking at which month did Ghana recorded high covid cases and death
Gh_month['cases']
# Out:
# month
# 3        84
# 4      1519
# 5      6097
# 6      9583
# 7     17791
# 8      9063
# 9      2277
# 10      691
# Name: cases, dtype: int64

# %%
Gh_month['cases'].plot.bar()
plt.title('Number of covid cases in Ghana per each month')
plt.xlabel('Month')
plt.ylabel('Number of cases')
plt.show()

# %%
Gh_month['deaths']
# Out:
# month
# 3       2
# 4      11
# 5      19
# 6      77
# 7      63
# 8     101
# 9      25
# 10      9
# Name: deaths, dtype: int64

# %%
Gh_month['deaths'].plot.bar()
plt.title('Number of covid death cases in Ghana per each month')
plt.xlabel('Month')
plt.ylabel('Number of death cases')
plt.show()

# %%
Gh_month[['cases','deaths']]
# Out:
#        cases  deaths
# month
# 3         84       2
# 4       1519      11
# 5       6097      19
# 6       9583      77
# 7      17791      63
# 8       9063     101
# 9       2277      25
# 10       691       9

# %%
Gh_month[['cases','deaths']].plot.bar()
plt.title('comparing recorded cases and deaths in Ghana per each month')
plt.xlabel('Month')
plt.ylabel('Number of death cases and recorded cases')
plt.show()

# %%
#percentage of Ghanains who had the covid based on the population
Gh_percent=sum(Ghana['cases'])/sum(Ghana['popData2019'])*100
Gh_percent
# Out:
# 0.0007591161177262976

# %%
#percentage of Ghanains who died from covid per the recorded cases
Gh_dpercent=sum(Ghana['deaths'])/sum(Ghana['cases'])*100
Gh_dpercent
# Out:
# 0.6517354845557796
